# %%
# Import required libraries
import pandas as pd
import dash
from dash import html, dcc
#import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
csv_path = r"C:\Users\almah\Downloads\spacex_launch_dash.csv"
spacex_df = pd.read_csv(csv_path, sep=",")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

#slider parameters
min_value =0
max_value =10000
# Create an app layout
#array(['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40'], dtype=object)
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',options = [
                                    {"label":"All Sites", "value":"All"},
                                    {"label":"CCAFS LC-40", "value":"CCAFS LC-40"},
                                    {"label":"VAFB SLC-4E", "value":"VAFB SLC-4E"},
                                    {"label":"CCAFS SLC-40", "value":"CCAFS SLC-40"},
                                    {"label":"KSC LC-39A", "value":"KSC LC-39A"}
                                ],
                                value = 'All',
                                placeholder = "Select Launch Site here",
                                searchable = True
                                ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0', 100: '100'},
                                                value=[min_value, max_value]),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output

# Function decorator to specify function input and output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Over All Success Rate')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df = filtered_df[filtered_df["Launch Site"] == entered_site]
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title=f'{entered_site} Sucess Rate')
        return fig
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
            [Input(component_id="payload-slider", component_property="value"),
            Input(component_id="site-dropdown", component_property="value")]
            )
def get_scatter_chart(entered_site, slid_val):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.scatter(data_frame = filtered_df, x= "Payload Mass (kg)", y= "class", 
        title="Correlation between Payload and Success (All Sites)")
    else:
        filtered_df = filtered_df[filtered_df["Launch Site"]==entered_site]
        fig = px.scatter(data_frame = filtered_df, x= "Payload Mass (kg)", y= "class", 
        title=f"Correlation between Payload and Success {entered_site}")
# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# [2024-02-14 11:53:37,757] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\AppData\Local\Temp\ipykernel_19412\2664792881.py", line 89, in get_scatter_chart
#     filtered_df = filtered_df[filtered_df["Launch Site"]==entered_site]
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\common.py", line 81, in new_method
#     return method(self, other)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py", line 270, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (56,), (2,))
# [2024-02-14 11:53:44,707] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\AppData\Local\Temp\ipykernel_19412\2664792881.py", line 89, in get_scatter_chart
#     filtered_df = filtered_df[filtered_df["Launch Site"]==entered_site]
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\common.py", line 81, in new_method
#     return method(self, other)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py", line 270, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (56,), (2,))
# [2024-02-14 11:53:46,971] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\AppData\Local\Temp\ipykernel_19412\2664792881.py", line 89, in get_scatter_chart
#     filtered_df = filtered_df[filtered_df["Launch Site"]==entered_site]
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\common.py", line 81, in new_method
#     return method(self, other)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py", line 270, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (56,), (2,))
# [2024-02-14 11:53:52,365] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\AppData\Local\Temp\ipykernel_19412\2664792881.py", line 89, in get_scatter_chart
#     filtered_df = filtered_df[filtered_df["Launch Site"]==entered_site]
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\common.py", line 81, in new_method
#     return method(self, other)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py", line 270, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (56,), (2,))
# [2024-02-14 11:53:56,137] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "C:\Users\almah\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\AppData\Local\Temp\ipykernel_19412\2664792881.py", line 89, in get_scatter_chart
#     filtered_df = filtered_df[filtered_df["Launch Site"]==entered_site]
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\common.py", line 81, in new_method
#     return method(self, other)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\almah\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py", line 270, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (56,), (2,))

# %%
spacex_df.head()
# Out:
#    Unnamed: 0  Flight Number  Launch Site  class  Payload Mass (kg)  \
# 0           0              1  CCAFS LC-40      0                0.0
# 1           1              2  CCAFS LC-40      0                0.0
# 2           2              3  CCAFS LC-40      0              525.0
# 3           3              4  CCAFS LC-40      0              500.0
# 4           4              5  CCAFS LC-40      0              677.0
#
#   Booster Version Booster Version Category
# 0  F9 v1.0  B0003                     v1.0
# 1  F9 v1.0  B0004                     v1.0
# 2  F9 v1.0  B0005                     v1.0
# 3  F9 v1.0  B0006                     v1.0
# 4  F9 v1.0  B0007                     v1.0

# %%
spacex_df["Payload Mass (kg)"].value_counts()
# Out:
# Payload Mass (kg)
# 9600.00    5
# 3696.65    2
# 3600.00    2
# 0.00       2
# 500.00     2
# 2647.00    1
# 6070.00    1
# 475.00     1
# 2150.00    1
# 6460.00    1
# 2490.00    1
# 5600.00    1
# 5300.00    1
# 362.00     1
# 2708.00    1
# 6092.00    1
# 3669.00    1
# 553.00     1
# 3310.00    1
# 4990.00    1
# 5200.00    1
# 3500.00    1
# 2205.00    1
# 4230.00    1
# 6761.00    1
# 4600.00    1
# 525.00     1
# 2257.00    1
# 677.00     1
# 3170.00    1
# 3325.00    1
# 2296.00    1
# 1316.00    1
# 4535.00    1
# 4428.00    1
# 2216.00    1
# 2395.00    1
# 570.00     1
# 4159.00    1
# 1898.00    1
# 4707.00    1
# 1952.00    1
# 2034.00    1
# 5271.00    1
# 3136.00    1
# 4696.00    1
# 3100.00    1
# 5384.00    1
# Name: count, dtype: int64
